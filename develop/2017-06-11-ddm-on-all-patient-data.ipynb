# %% [markdown]
# # DDM for All Patient Data
#
# Parse all patient data to a single CSV, then check if subject data can fit a hierarchical drift decision model for different stimuli types

# %% [markdown]
# Experimental stimuli are as follows:
# - Condition 1: Same stimuli (see cat / hear cat) -- `SS`
# - Condition 2: Phonologically congruent (see cat / hear hat) -- `CP`
# - Condition 3: Semantically congruent (see cat / hear dog) -- `CS`
# - Condition 4: Unrelated stimuli (see house / hear cat)  -- `US`

# %% [markdown]
# ### Parse all subject data to single csv
#
# Generate a single csv for all data, using `subject_idx` as a unique patient identifier.
# Also give conditions (`stim`) a 2-character descriptive instead of a number.
#
# CSV fields are as follows:
# - `subj_idx`: Unique subject identifier
# - `rt`: Reaction time
# - `stim`: Stimulus (SS/CP/CS/US)
# - `response`: Response to stimulus (True(1)/False(0))

# %%
def parse_condition(stim_num):
    if stim_num == '1':
        return 'SS'
    if stim_num == '2':
        return 'CP'
    if stim_num == '3':
        return 'CS'
    if stim_num == '4':
        return 'US'

# %%
import csv
import glob 


csv_dir = '../data/pilot_subjects/'
subjects = []

for csv_file in glob.glob(csv_dir + 'data*.csv'):
    subject = []
    subj_idx = csv_file[-9:-4]  # Use id from filename
    with open(csv_file, 'r') as f:
        reader = csv.DictReader(f)
        for trial in reader:
            trial['subj_idx'] = subj_idx
            trial['stim'] = parse_condition(trial['stim'])
            subject.append(trial)
    subjects.append(subject)
    
keys = subject[0].keys()
print(keys)


with open('../data/all_subjects.csv', 'w') as out:
        writer = csv.DictWriter(out, keys)
        writer.writeheader()
        for subj in subjects:
            writer.writerows(subj)
        
print(subjects)
# Out:
# dict_keys(['rt', 'stim', 'response', 'subj_idx'])
# [[{'rt': '1.061641823966056', 'stim': 'CP', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8477577275280055', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.9304584711371717', 'stim': 'CS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8855503492450225', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.9682304077978188', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8823385527502978', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.0849957736209035', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8961766242446174', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.9467479459653987', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.0767629856018175', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.7600004304586037', 'stim': 'CP', 'response': '1.0', 'subj_idx': '17991'}, {'rt': 'nan', 'stim': 'SS', 'response': 'nan', 'subj_idx': '17991'}, {'rt': '0.9432769019695115', 'stim': 'CP', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.3063802560700424', 'stim': 'CP', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8419402966428606', 'stim': 'CS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.2605568331910035', 'stim': 'CP', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.7405581372640881', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.7671724092306249', 'stim': 'CP', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.1384052042667463', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.060795544355642', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8789235331660166', 'stim': 'CP', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.3295975826840731', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.314017232032711', 'stim': 'CS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.1139803148889769', 'stim': 'CS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8280877934339514', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.959286922492538', 'stim': 'CS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.873799372026042', 'stim': 'CP', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.9086083765578223', 'stim': 'CS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.7671133528965584', 'stim': 'CP', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8177300842871773', 'stim': 'CS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8363883305046329', 'stim': 'CS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.823004563259019', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.7937495852493157', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8516607845176623', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8623429966992262', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.04093452088091', 'stim': 'CS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.7801736758719926', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8388244027737528', 'stim': 'CP', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.128898199292962', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.7479639681696426', 'stim': 'CS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8381132693448308', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.56119969219435', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.6967689575412805', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.9312433242212137', 'stim': 'US', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.8219087124343787', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.5689854670199566', 'stim': 'CS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '0.9605035028198472', 'stim': 'SS', 'response': '1.0', 'subj_idx': '17991'}, {'rt': '1.2750551090175577', 'stim': 'US', 'response': '1.0', 'subj_idx': '1 ...
