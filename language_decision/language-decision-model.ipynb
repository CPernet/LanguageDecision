# %% [markdown]
# # Language Decision Model

# %%
import hddm

hddm.__dict__
# Out:
# /Users/constantinose/anaconda/envs/lang-dec/lib/python3.5/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)
# {'AccumulatorModel': hddm.models.base.AccumulatorModel,
#  'HDDM': hddm.models.hddm_info.HDDM,
#  'HDDMBase': hddm.models.base.HDDMBase,
#  'HDDMRegressor': hddm.models.hddm_regression.HDDMRegressor,
#  'HDDMStimCoding': hddm.models.hddm_stimcoding.HDDMStimCoding,
#  'HDDMTransformed': hddm.models.hddm_transformed.HDDMTransformed,
#  'HDDMTruncated': hddm.models.hddm_truncated.HDDMTruncated,
#  'Tracer': IPython.core.debugger.Tracer,
#  '__builtins__': {'ArithmeticError': ArithmeticError,
#   'AssertionError': AssertionError,
#   'AttributeError': AttributeError,
#   'BaseException': BaseException,
#   'BlockingIOError': BlockingIOError,
#   'BrokenPipeError': BrokenPipeError,
# ...
